# %% [markdown]
# # Library Imports

# %%
from __future__ import print_function, division
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, LeakyReLU, ReLU, Reshape,Conv2D, Flatten, Dropout, Conv2DTranspose, BatchNormalization, Embedding, Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

import matplotlib.pyplot as plt
import os
import cv2
import tqdm
from random import shuffle # mixing up or currently ordered data that might lead our network astray in training.
import numpy as np

# %%
for dirname, _, filenames in os.walk('C:/Users/Keravnos/Downloads/archive'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\1.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\10.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\100.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\101.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\102.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\103.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\104.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\105.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\106.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\107.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\108.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\109.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\11.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\110.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\111.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\112.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\113.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\114.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\115-mega.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\115.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\116.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\117.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\118.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\119.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\12.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\120.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\121.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\122.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\123.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\124.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\125.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\126.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\127-mega.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\127.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\128.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\129.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\13.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\130-mega.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\130.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\131.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\132.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\133.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\134.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\135.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\136.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\137.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\138.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\139.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\14.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\140.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\141.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\142-mega.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\142.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\143.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\144.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\145.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\146.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\147.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\148.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\149.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\15-mega.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\15.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\150-mega-x.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\150-mega-y.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\150.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\151.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\152.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\153.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\154.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\155.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\156.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\157.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\158.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\159.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\16.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\160.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\161.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\162.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\163.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\164.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\165.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\166.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\167.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\168.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\169.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\17.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\170.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\171.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\172.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\173.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\174.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\175.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\176.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\177.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\178.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\179.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\18-mega.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\18.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\180.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\181-mega.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\181.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\182.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\183.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\184.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\185.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\186.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\187.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\188.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\189.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\19.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\190.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\191.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\192.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\193.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\194.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\195.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\196.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\197.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\198.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\199.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\2.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\20.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\200.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\201-f.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\202.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\203.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\204.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\205.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\206.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\207.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\208-mega.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\208.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\209.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\21.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\210.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\211.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\212-mega.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\212.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\213.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\214-mega.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\214.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\215.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\216.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\217.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\218.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\219.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\22.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\220.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\221.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\222.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\223.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\224.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\225.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\226.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\227.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\228.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\229-mega.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\229.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\23.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\230.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\231.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\232.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\233.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\234.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\235.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\236.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\237.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\238.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\239.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\24.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\240.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\241.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\242.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\243.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\244.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\245.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\246.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\247.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\248-mega.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\248.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\249.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\25-belle.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\25-libre.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\25-phd.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\25-pop-star.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\25-rock-star.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\25.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\250.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\251.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\252.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\253.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\254-mega.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\254.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\255.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\256.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\257-mega.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\257.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\258.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\259.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\26.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\260-mega.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\260.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\261.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\262.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\263.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\264.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\265.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\266.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\267.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\268.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\269.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\27.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\270.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\271.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\272.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\273.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\274.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\275.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\276.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\277.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\278.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\279.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\28.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\280.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\281.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\282-mega.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\282.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\283.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\284.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\285.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\286.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\287.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\288.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\289.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\29.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\290.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\291.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\292.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\293.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\294.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\295.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\296.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\297.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\298.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\299.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\3-mega.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\3.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\30.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\300.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\301.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\302-mega.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\302.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\303-mega.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\303.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\304.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\305.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\306-mega.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\306.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\307.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\308-mega.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\308.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\309.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\31.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\310-mega.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\310.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\311.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\312.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\313.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\314.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\315.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\316.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\317.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\318.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\319-mega.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\319.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\32.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\320.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\321.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\322.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\323-mega.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\323.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\324.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\325.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\326.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\327.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\328.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\329.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\33.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\330.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\331.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\332.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\333.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\334-mega.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\334.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\335.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\336.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\337.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\338.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\339.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\34.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\340.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\341.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\342.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\343.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\344.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\345.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\346.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\347.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\348.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\349.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\35.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\350.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\351.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\352.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\353.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon\354-mega.png
# C:/Users/Keravnos/Downloads/archive\pokemon\pokemon
jpg
# C:/Users/Keravnos/Downloads/archive\pokemon_jpg\pokemon_jpg\87.jpg
# C:/Users/Keravnos/Downloads/archive\pokemon_jpg\pokemon_jpg\88.jpg
# C:/Users/Keravnos/Downloads/archive\pokemon_jpg\pokemon_jpg\89.jpg
# C:/Users/Keravnos/Downloads/archive\pokemon_jpg\pokemon_jpg\9-mega.jpg
# C:/Users/Keravnos/Downloads/archive\pokemon_jpg\pokemon_jpg\9.jpg
# C:/Users/Keravnos/Downloads/archive\pokemon_jpg\pokemon_jpg\90.jpg
# C:/Users/Keravnos/Downloads/archive\pokemon_jpg\pokemon_jpg\91.jpg
# C:/Users/Keravnos/Downloads/archive\pokemon_jpg\pokemon_jpg\92.jpg
# C:/Users/Keravnos/Downloads/archive\pokemon_jpg\pokemon_jpg\93.jpg
# C:/Users/Keravnos/Downloads/archive\pokemon_jpg\pokemon_jpg\94-mega.jpg
# C:/Users/Keravnos/Downloads/archive\pokemon_jpg\pokemon_jpg\94.jpg
# C:/Users/Keravnos/Downloads/archive\pokemon_jpg\pokemon_jpg\95.jpg
# C:/Users/Keravnos/Downloads/archive\pokemon_jpg\pokemon_jpg\96.jpg
# C:/Users/Keravnos/Downloads/archive\pokemon_jpg\pokemon_jpg\97.jpg
# C:/Users/Keravnos/Downloads/archive\pokemon_jpg\pokemon_jpg\98.jpg
# C:/Users/Keravnos/Downloads/archive\pokemon_jpg\pokemon_jpg\99.jpg

# %%
def build_generator():
    
    noise = Input(shape=(latent_dim,))
    label = Input(shape=(1,), dtype='int32')

    # embedding for categorical input
    li = Embedding(num_classes, latent_dim)(label)
    # linear multiplication
    scale = int(img_shape[0]/4)
    n_nodes = scale*scale
    li = Dense(n_nodes)(li)
    # reshape to additional channel
    li = Reshape((scale, scale, 1))(li)
    # foundation for 256x256 image but scaled down
    n_nodes = 4 * scale * scale
    gen = Dense(n_nodes)(noise)
    gen = ReLU(0.2)(gen)
    # gen = Dropout(0.5)(gen)
    gen = Reshape((scale, scale, 4))(gen)
    # merge image gen and label input
    merge = Concatenate()([gen, li])
    # upsample
    gen = Conv2DTranspose(4, (4,4), strides=(2,2), padding='same')(merge)
    gen = ReLU(0.2)(gen)
    gen = BatchNormalization(momentum=0.4, epsilon=0.002,)(gen)
    # gen = Dropout(0.5)(gen)
    # upsample
    gen = Conv2DTranspose(4, (4,4), strides=(2,2), padding='same')(gen)
    gen = ReLU(0.2)(gen)
    gen = BatchNormalization(momentum=0.4, epsilon=0.002,)(gen)
    # gen = Dropout(0.5)(gen)
    # output layer
    out_layer = Conv2D(1, (img_shape[0], img_shape[1]), activation='tanh', padding='same')(gen)
    # create Model object to return
    model = Model([noise, label], out_layer)
    model.summary()

    return model

# %%
def build_discriminator():

    # label input
    label = Input(shape=(1,), dtype='int32')
    # embedding for categorical input
    li = Embedding(num_classes, latent_dim)(label)
    # scale up to image dimensions with linear activation
    n_nodes = np.prod( img_shape)
    li = Dense(n_nodes)(li)
    # reshape to additional channel
    li = Reshape(img_shape)(li)
    # image input
    img = Input(shape=img_shape)
    # concat label as a channel
    merge = Concatenate()([img, li])
    # downsample
    fe = Conv2D(128, (3,3), strides=(2,2), padding='same')(merge)
    fe = LeakyReLU(alpha=0.2)(fe)
    fe = Dropout(0.2)(fe)
    # downsample
    fe = Conv2D(256, (3,3), strides=(2,2), padding='same')(fe)
    fe = LeakyReLU(alpha=0.2)(fe)
    # downsample
    fe = Conv2D(512, (3,3), strides=(2,2), padding='same')(fe)
    fe = LeakyReLU(alpha=0.2)(fe)
    # dropout
    fe = Dropout(0.2)(fe)
    # flatten feature maps
    fe = Flatten()(fe)
    # output
    out_layer = Dense(1, activation='sigmoid')(fe)
    # define model
    model = Model([img, label], out_layer)

    sopt = Adam(learning_rate=0.0002, beta_1=0.5)

    model.compile(loss=['binary_crossentropy'],
                                optimizer=sopt,
                                metrics=['accuracy'])

    return model

# %%
def prepare_data(dir):
        train_imgs = []
        train_labels = []

        folders = os.listdir(im_dir)
        for fldr in folders:
            print('COLLECTING IMAGES FROM', fldr, '...')
            next_folder_path = os.path.join(im_dir, fldr)
            img_list = os.listdir(next_folder_path)

            for img in tqdm.tqdm(img_list):
                img_path = os.path.join(next_folder_path, img)
                # load the image
                image = cv2.imread(img_path, cv2.IMREAD_COLOR)
                # resize to dimensions specified in class
                image = cv2.resize(image, (img_rows, img_cols), interpolation=cv2.INTER_AREA)
                # append image and label to export lists
                train_imgs.append(image)
                ind = folders.index(fldr)
                train_labels.append(ind)

        train_imgs = np.array(train_imgs)
        train_labels = np.array(train_labels)
        return train_imgs, train_labels

# %%
def train(epochs, batch_size=128, sample_interval=50):

    X_train, y_train = prepare_data(pokemon_img_path)

    # convert from ints to floats and scale from [0,255] to [-1,1]
    X_train = (X_train.astype(np.float32) - 127.5) / 127.5
    # expand to 3d, e.g. add channels
    X_train = np.expand_dims(X_train, axis=3)
    y_train = y_train.reshape(-1, )

    print('X SHAPE:', X_train.shape, 'Y SHAPE:', y_train.shape)

    # Adversarial ground truths
    valid = np.ones((batch_size, 1))
    fake = np.zeros((batch_size, 1))

    for epoch in range(epochs):

        # ---------------------
        #  Train Discriminator
        # ---------------------

        # Select a random half batch of images
        idx = np.random.randint(0, X_train.shape[0], batch_size)
        imgs, labels = X_train[idx], y_train[idx]

        # Sample noise as generator input
        noise = np.random.normal(0, 1, (batch_size, 100))

        # Generate a half batch of new images
        gen_imgs = generator.predict([noise, labels])

        # Train the discriminator
        d_loss_real = discriminator.train_on_batch([imgs, labels], valid)
        d_loss_fake = discriminator.train_on_batch([gen_imgs, labels], fake)
        d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)

        # ---------------------
        #  Train Generator
        # ---------------------

        # Condition on labels
        sampled_labels = np.random.randint(0, num_classes, batch_size).reshape(-1, 1)

        # Train the generator
        g_loss = combined.train_on_batch([noise, sampled_labels], valid)

        # Plot the progress
        print("%d [D loss: %f, acc.: %.2f%%] [G loss: %f]" % (epoch, d_loss[0], 100 * d_loss[1], g_loss))

        # If at save interval => save generated image samples and model checkpoints
        if epoch % sample_interval == 0:
            sample_images(epoch)
            if epoch % 2000 == 0:
                # ---------------------
                #  SAVING CHECKPOINTS
                # ---------------------
                os.mkdir('models/model_at_{}'.format(epoch))
                model_path = os.path.join('models/model_at_{}'.format(epoch), "model_at_{}.json".format(epoch))
                # serialize model to JSON
                model_json = generator.to_json()
                with open(model_path, "w") as json_file:
                    json_file.write(model_json)
                # serialize weights to HDF5
                generator.save_weights(os.path.join('models/model_at_{}'.format(epoch), "model_at_{}.h5".format(epoch)))

# %%
def sample_images(epoch):
    r, c = 2, 5
    noise = np.random.normal(0, 1, (r * c, 100))
    sampled_labels = np.arange(0, 10).reshape(-1, 1)

    gen_imgs = generator.predict([noise, sampled_labels])

    # Rescale images 0 - 1
    gen_imgs = 0.5 * gen_imgs + 0.5

    fig, axs = plt.subplots(r, c)
    cnt = 0
    for i in range(r):
        for j in range(c):
            axs[i,j].imshow(gen_imgs[cnt,:,:,0], cmap='gray')
            axs[i,j].set_title("Scan: %d" % sampled_labels[cnt])
            axs[i,j].axis('off')
            cnt += 1
    
    fig.savefig(os.path.join('output', '%d.png' % epoch))
    plt.close()

# %%
# Input shape
img_rows = 256
img_cols = 256
channels = 3
img_shape = (img_rows, img_cols, channels)
num_classes = 10
latent_dim = 100
epochs=20000
batch_size=32
sample_interval=200


pokemon_img_path = 'C:/Users/Keravnos/Downloads/archive/pokemon/pokemon'

# create output folder
try:
    os.mkdir('output')
except FileExistsError:
    print('OUTPUT DIRECTORIES EXISTS! NO NEED TO GENERATE')
try:
    os.mkdir('models')
except FileExistsError:
    print('CHECKPOINT DIRECTORY EXISTS! NO NEED TO GENERATE')

optimizer = Adam(learning_rate=0.0002, beta_1=0.5)

# Build and compile the discriminator
discriminator = build_discriminator()
discriminator.summary()

# Build the generator
generator = build_generator()

# The generator takes noise and the target label as input
# and generates the corresponding digit of that label
noise = Input(shape=(latent_dim,))
label = Input(shape=(1,))
img = generator([noise, label])

# For the combined model we will only train the generator
discriminator.trainable = False

# The discriminator takes generated image as input and determines validity
# and the label of that image
valid = discriminator([img, label])

# The combined model  (stacked generator and discriminator)
# Trains generator to fool discriminator
combined = Model([noise, label], valid)
combined.compile(loss=['binary_crossentropy'],
    optimizer=optimizer)
# Out:
# OUTPUT DIRECTORIES EXISTS! NO NEED TO GENERATE
# CHECKPOINT DIRECTORY EXISTS! NO NEED TO GENERATE
# Model: "model_11"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_58 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# embedding_16 (Embedding)        (None, 1, 100)       1000        input_58[0][0]
# __________________________________________________________________________________________________
# dense_23 (Dense)                (None, 1, 196608)    19857408    embedding_16[0][0]
# __________________________________________________________________________________________________
# input_59 (InputLayer)           [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# reshape_9 (Reshape)             (None, 256, 256, 3)  0           dense_23[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 256, 256, 6)  0           input_59[0][0]
#                                                                  reshape_9[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 128, 128, 128 7040        concatenate_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 128, 128, 128 0           conv2d_64[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 128, 128, 128 0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 64, 64, 256)  295168      dropout_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 64, 64, 256)  0           conv2d_65[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 32, 32, 512)  1180160     leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 32, 32, 512)  0           conv2d_66[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 32, 32, 512)  0           leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# flatten_23 (Flatten)            (None, 524288)       0           dropout_12[0][0]
# __________________________________________________________________________________________________
# dense_24 (Dense)                (None, 1)            524289      flatten_23[0][0]
# ==================================================================================================
# Total params: 21,865,065
# Trainable params: 21,865,065
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "model_12"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_60 (InputLayer)           [(None, 100)]        0
# __________________________________________________________________________________________________
# input_61 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# dense_26 (Dense)                (None, 16384)        1654784     input_60[0][0]
# __________________________________________________________________________________________________
# embedding_17 (Embedding)        (None, 1, 100)       1000        input_61[0][0]
# __________________________________________________________________________________________________
# re_lu_6 (ReLU)                  (None, 16384)        0           dense_26[0][0]
# __________________________________________________________________________________________________
# dense_25 (Dense)                (None, 1, 4096)      413696      embedding_17[0][0]
# __________________________________________________________________________________________________
# reshape_11 (Reshape)            (None, 64, 64, 4)    0           re_lu_6[0][0]
# __________________________________________________________________________________________________
# reshape_10 (Reshape)            (None, 64, 64, 1)    0           dense_25[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 64, 64, 5)    0           reshape_11[0][0]
#                                                                  reshape_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 128, 128, 4)  324         concatenate_3[0][0]
# __________________________________________________________________________________________________
# re_lu_7 (ReLU)                  (None, 128, 128, 4)  0           conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 128, 128, 4)  16          re_lu_7[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 256, 256, 4)  260         batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# re_lu_8 (ReLU)                  (None, 256, 256, 4)  0           conv2d_transpose_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 256, 256, 4)  16          re_lu_8[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 256, 256, 1)  262145      batch_normalization_63[0][0]
# ==================================================================================================
# Total params: 2,332,241
# Trainable params: 2,332,225
# Non-trainable params: 16
# __________________________________________________________________________________________________
# WARNING:tensorflow:Model was constructed with shape (None, 256, 256, 3) for input KerasTensor(type_spec=TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name='input_59'), name='input_59', description="created by layer 'input_59'"), but it was called on an input with incompatible shape (None, 256, 256, 1).
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21336/1102431991.py in <module>
#      43 # The discriminator takes generated image as input and determines validity
#      44 # and the label of that image
# ---> 45 valid = discriminator([img, label])
#      46
#      47 # The combined model  (stacked generator and discriminator)
#
# c:\Users\Keravnos\Downloads\POKEGAN\venv\lib\site-packages\keras\engine\base_layer.py in __call__(self, *args, **kwargs)
#     974     # >> model = tf.keras.Model(inputs, outputs)
#     975     if _in_functional_construction_mode(self, inputs, args, kwargs, input_list):
# --> 976       return self._functional_construction_call(inputs, args, kwargs,
#     977                                                 input_list)
#     978
#
# c:\Users\Keravnos\Downloads\POKEGAN\venv\lib\site-packages\keras\engine\base_layer.py in _functional_construction_call(self, inputs, args, kwargs, input_list)
#    1112         layer=self, inputs=inputs, build_graph=True, training=training_value):
#    1113       # Check input assumptions set after layer building, e.g. input shape.
# -> 1114       outputs = self._keras_tensor_symbolic_call(
#    1115           inputs, input_masks, args, kwargs)
#    1116
#
# c:\Users\Keravnos\Downloads\POKEGAN\venv\lib\site-packages\keras\engine\base_layer.py in _keras_tensor_symbolic_call(self, inputs, input_masks, args, kwargs)
#     846       return tf.nest.map_structure(keras_tensor.KerasTensor, output_signature)
#     847     else:
# --> 848       return self._infer_output_signature(inputs, args, kwargs, input_masks)
#     849
#     850   def _infer_output_signature(self, inputs, args, kwargs, input_masks):
#
# c:\Users\Keravnos\Downloads\POKEGAN\venv\lib\site-packages\keras\engine\base_layer.py in _infer_output_signature(self, inputs, args, kwargs, input_masks)
#     886           self._maybe_build(inputs)
#     887           inputs = self._maybe_cast_inputs(inputs)
# --> 888           outputs = call_fn(inputs, *args, **kwargs)
#     889
#     890         self._handle_activity_regularization(inputs, outputs)
#
# c:\Users\Keravnos\Downloads\POKEGAN\venv\lib\site-packages\keras\engine\functional.py in call(self, inputs, training, mask)
#     412         a list of tensors if there are more than one outputs.
#     413     """
# --> 414     return self._run_internal_graph(
#     415         inputs, training=training, mask=mask)
#     416
#
# c:\Users\Keravnos\Downloads\POKEGAN\venv\lib\site-packages\keras\engine\functional.py in _run_internal_graph(self, inputs, training, mask)
#     548
#     549         args, kwargs = node.map_arguments(tensor_dict)
# --> 550         outputs = node.layer(*args, **kwargs)
#     551
#     552         # Update tensor_dict.
#
# c:\Users\Keravnos\Downloads\POKEGAN\venv\lib\site-packages\keras\engine\base_layer.py in __call__(self, *args, **kwargs)
#    1018         training=training_mode):
#    1019
# -> 1020       input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#    1021       if eager:
#    1022         call_fn = self.call
#
# c:\Users\Keravnos\Downloads\POKEGAN\venv\lib\site-packages\keras\engine\input_spec.py in assert_input_compatibility(input_spec, inputs, layer_name)
#     248           value = value.value
#     249         if value is not None and shape_as_list[int(axis)] not in {value, None}:
# --> 250           raise ValueError(
#     251               'Input ' + str(input_index) + ' of layer ' + layer_name + ' is'
#     252               ' incompatible with the layer: expected axis ' + str(axis) +
#
# ValueError: Input 0 of layer conv2d_64 is incompatible with the layer: expected axis -1 of input shape to have value 6 but received input with shape (None, 256, 256, 4)
